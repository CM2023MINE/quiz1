# %% [markdown]
# <a href="https://colab.research.google.com/github/datascience-uniandes/data-quality-tutorial/blob/master/data-quality-tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Quality and Cleanliness
#
# MINE-4101: Applied Data Science
# Univerisdad de los Andes
#
# **Dataset:** Homicides Colombia ([datos.gov.co](datos.gov.co))
#
# Last update: September, 2023

# %%
# !pip install pylev
# Out:
# Requirement already satisfied: pylev in c:\users\carlos.montana\appdata\local\anaconda3\lib\site-packages (1.4.0)

# %%
import re
from random import randint
from datetime import datetime
from difflib import SequenceMatcher

import numpy as np
import pandas as pd

import pylev

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## 1. Loading the data

# %%
homicides_df = pd.read_csv("./data/homicides.csv")

# %%
homicides_df.shape
# Out:
# (12400, 22)

# %%
homicides_df.dtypes
# Out:
# FECHA                 object
# DEPARTAMENTO          object
# MUNICIPIO             object
# DIA                   object
# HORA                  object
# BARRIO                object
# ZONA                  object
# CLASE DE SITIO        object
# ARMA O MEDIO          object
# MOVIL VICTIMA         object
# MOVIL AGRESOR         object
# EDAD                 float64
# GENERO                object
# ESTADO CIVIL          object
# CLASE EMPLEADO        object
# PROFESION             object
# ESCOLARIDAD           object
# PAIS NACE             object
# CODIGO DANE          float64
# AÑO DE NACIMIENTO    float64
# CÉDULA                object
# CORREO                object
# dtype: object

# %%
homicides_df.sample(5)
# Out:
#                         FECHA  DEPARTAMENTO          MUNICIPIO      DIA  \
# 4744   05/24/2021 12:00:00 AM  CUNDINAMARCA   BOGOTÁ D.C. (CT)  Domingo
# 7838   08/21/2021 12:00:00 AM         CAUCA       POPAYÁN (CT)  Viernes
# 11360  12/06/2021 12:00:00 AM  CUNDINAMARCA         FUSAGASUGÁ  Domingo
# 8082   08/29/2021 12:00:00 AM     ANTIOQUIA      MEDELLÍN (CT)   Sábado
# 11880  12/20/2021 12:00:00 AM     ATLÁNTICO  BARRANQUILLA (CT)  Domingo
#
#         HORA                                    BARRIO    ZONA  \
# 4744   12:30  URB. RIVERAS DE OCCIDENTE ENO REPORTADO8  URBANA
# 7838    0:13                         VALLE DEL ORTIGAL  URBANA
# 11360  22:30                             CARLOS LLERAS  URBANA
# 8082    3:26              BARRIO COLON CNO REPORTADO10  URBANA
# 11880  12:15                                 EL BOSQUE  URBANA
#
#               CLASE DE SITIO   ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD  \
# 4744   DENTRO DE LA VIVIENDA    ARMA BLANCA         A PIE         A PIE  20.0
# 7838             APARTAMENTO  ARMA DE FUEGO         A PIE         A PIE  41.0
# 11360          VIAS PUBLICAS    ARMA BLANCA         A PIE         A PIE  27.0
# 8082           VIAS PUBLICAS    ARMA BLANCA         A PIE         A PIE  43.0
# 11880          VIAS PUBLICAS   CONTUNDENTES         A PIE         A PIE  18.0
#
#           GENERO ESTADO CIVIL       CLASE EMPLEADO     PROFESION ESCOLARIDAD  \
# 4744   MASCULINO      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# 7838    FEMENINO       CASADO        INDEPENDIENTE  NO REPORTADO  SECUNDARIA
# 11360  MASCULINO      SOLTERO          DESEMPLEADO  NO REPORTADO    PRIMARIA
# 8082   MASCULINO  UNION LIBRE     AFRODESCENDIENTE  NO REPORTADO  SECUNDARIA
# 11880  MASCULINO  UNION LIBRE  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
#
#       PAIS NACE  CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA  \
# 4744   COLOMBIA   11001000.0             1995.0  65-535
# 7838   COLOMBIA   19001000.0             1974.0  95-962
# 11360  COLOMBIA   25290000.0             1988.0  17-762
# 8082   COLOMBIA    5001000.0             1972.0  48-580
# 11880  COLOMBIA    8001000.0             1997.0  41-673
#
#                            CORREO
# 4744         solbhk5399@gmail.com
# 7838   bnsnul3698@unidatos.edu.co
# 11360  bapnnu7022@unidatos.edu.co
# 8082         paannr9731@gmail.com
# 11880  lmstut1842@unidatos.edu.co

# %% [markdown]
# ## 2. Working with datetimes

# %%
# Creating a lambda expression for datetime parsing
dateparse = lambda x: datetime.strptime(x, "%m/%d/%Y %H:%M:%S %p")

# %%
# Applying the validation to all values in the column
homicides_df["FECHA"].apply(dateparse)

# IT IS EXPECTED TO HAVE AN ERROR BECAUSE SOME VALUES DOESN'T FIT THE FORMAT
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Applying the validation to all values in the column
# ----> 2 homicides_df["FECHA"].apply(dateparse)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[2], line 2, in <lambda>(x)
#       1 # Creating a lambda expression for datetime parsing
# ----> 2 dateparse = lambda x: datetime.strptime(x, "%m/%d/%Y %H:%M:%S %p")
#
# File ~\AppData\Local\anaconda3\Lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File ~\AppData\Local\anaconda3\Lib\_strptime.py:349, in _strptime(data_string, format)
#     347 found = format_regex.match(data_string)
#     348 if not found:
# --> 349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
#     352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#
# ValueError: time data '13/12/2021 12:00:00 AM' does not match format '%m/%d/%Y %H:%M:%S %p'

# %%
# Creating a function for validating which value is causing the previous error
def error_in_format(x):
    try:
        datetime.strptime(x, "%m/%d/%Y %H:%M:%S %p")
        return False
    except:
        return True

# %%
# Using the function for validation
homicides_df.loc[homicides_df["FECHA"].apply(error_in_format)]
# Out:
#                         FECHA DEPARTAMENTO       MUNICIPIO      DIA   HORA  \
# 486    13/12/2021 12:00:00 AM        VALLE       CALI (CT)    kunes  23:00
# 695    30/01/2021 12:00:00 AM      BOLÍVAR  CARTAGENA (CT)    Lunes   5:30
# 1250   18/05/2021 12:00:00 AM        HUILA         TESALIA   Jueves  19:30
# 12168  12/25/2021 12:00:00 MM        VALLE         PALMIRA  Viernes  15:30
# 12399                   TOTAL          NaN             NaN      NaN    NaN
#
#                 BARRIO    ZONA       CLASE DE SITIO   ARMA O MEDIO  \
# 486         MOJICA E15  URBANA        VIAS PUBLICAS  ARMA DE FUEGO
# 695    REP. DEL LIBANO  URBANA        VIAS PUBLICAS    ARMA BLANCA
# 1250    VEREDA PACARNI   RURAL  CASAS DE HABITACION  ARMA DE FUEGO
# 12168        LA EMILIA  URBANA        VIAS PUBLICAS  ARMA DE FUEGO
# 12399              NaN     NaN                  NaN            NaN
#
#       MOVIL VICTIMA          MOVIL AGRESOR  EDAD     GENERO ESTADO CIVIL  \
# 486           A PIE                  A PIE  26.0  MASCULINO      SOLTERO
# 695    NO REPORTADO                  A PIE  25.0  MASCULINO      SOLTERO
# 1250          A PIE                  A PIE  34.0   FEMENINO      SOLTERO
# 12168         A PIE  CONDUCTOR MOTOCICLETA  17.0  MASCULINO      SOLTERO
# 12399           NaN                    NaN   NaN        NaN          NaN
#
#             CLASE EMPLEADO     PROFESION ESCOLARIDAD PAIS NACE  CODIGO DANE  \
# 486          INDEPENDIENTE  NO REPORTADO  SECUNDARIA  COLOMBIA   76001000.0
# 695    EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  COLOMBIA   13001000.0
# 1250            AGRICULTOR  NO REPORTADO    PRIMARIA  COLOMBIA   41797000.0
# 12168  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  COLOMBIA   76520000.0
# 12399                  NaN           NaN         NaN       NaN          NaN
#
#        AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 486                 89.0  80-330        lujhdf9132@gmail.com
# 695               1990.0  12-915  ghumtg4094@unidatos.edu.co
# 1250              1981.0  99-095        sdaggf6639@gmail.com
# 12168             1998.0  16-362        uschca1775@gmail.com
# 12399                NaN     NaN                         NaN

# %%
# Deleting a row by its index
homicides_df.drop([486, 695, 1250, 12168, 12399], inplace=True)

# %%
# Trying to parse the datetime string again
homicides_df["FECHA"] = homicides_df["FECHA"].apply(dateparse)

# %%
homicides_df.dtypes
# Out:
# FECHA                datetime64[ns]
# DEPARTAMENTO                 object
# MUNICIPIO                    object
# DIA                          object
# HORA                         object
# BARRIO                       object
# ZONA                         object
# CLASE DE SITIO               object
# ARMA O MEDIO                 object
# MOVIL VICTIMA                object
# MOVIL AGRESOR                object
# EDAD                        float64
# GENERO                       object
# ESTADO CIVIL                 object
# CLASE EMPLEADO               object
# PROFESION                    object
# ESCOLARIDAD                  object
# PAIS NACE                    object
# CODIGO DANE                 float64
# AÑO DE NACIMIENTO           float64
# CÉDULA                       object
# CORREO                       object
# dtype: object

# %%
# Counting homicides by hour
homicides_df["FECHA"].dt.hour.value_counts()

# All datetime hour parts are the same
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Counting homicides by hour
# ----> 2 homicides_df["FECHA"].dt.hour.value_counts()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\accessors.py:512, in CombinedDatetimelikeProperties.__new__(cls, data)
#     509 elif is_period_dtype(data.dtype):
#     510     return PeriodProperties(data, orig)
# --> 512 raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %% [markdown]
# *The homicide hour is available in a different column!*

# %%
# Merging both columns
homicides_df["FECHA"] = homicides_df["FECHA"].astype(str).apply(lambda x: x[:11])+homicides_df["HORA"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HORA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Merging both columns
# ----> 2 homicides_df["FECHA"] = homicides_df["FECHA"].astype(str).apply(lambda x: x[:11])+homicides_df["HORA"]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'HORA'

# %%
# Deleting redundant column
homicides_df.drop(columns=["HORA"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Deleting redundant column
# ----> 2 homicides_df.drop(columns=["HORA"], inplace=True)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['HORA'] not found in axis"

# %%
# Making a new expression for datetime parsing
dateparse = lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M")

# %%
# Applying the expression
homicides_df["FECHA"] = homicides_df["FECHA"].apply(dateparse)

# %%
homicides_df.dtypes
# Out:
# FECHA                 object
# DEPARTAMENTO          object
# MUNICIPIO             object
# DIA                   object
# BARRIO                object
# ZONA                  object
# CLASE DE SITIO        object
# ARMA O MEDIO          object
# MOVIL VICTIMA         object
# MOVIL AGRESOR         object
# EDAD                 float64
# GENERO                object
# ESTADO CIVIL          object
# CLASE EMPLEADO        object
# PROFESION             object
# ESCOLARIDAD           object
# PAIS NACE             object
# CODIGO DANE          float64
# AÑO DE NACIMIENTO    float64
# CÉDULA                object
# CORREO                object
# dtype: object

# %%
homicides_df.sample(5)
# Out:
#                  FECHA DEPARTAMENTO          MUNICIPIO      DIA  \
# 6201   2021-07-02 6:50        VALLE              YUMBO   Jueves
# 8342   2021-09-06 8:45    ANTIOQUIA         COPACABANA  domungo
# 2775  2021-03-26 12:45    ATLÁNTICO  BARRANQUILLA (CT)   Jueves
# 8899  2021-09-22 23:55        VALLE          CALI (CT)    Mates
# 3666  2021-04-21 20:17    ANTIOQUIA           RIONEGRO   Martes
#
#                 BARRIO    ZONA CLASE DE SITIO   ARMA O MEDIO MOVIL VICTIMA  \
# 6201   CGTO MULALO E25   RURAL      CARRETERA  ARMA DE FUEGO         A PIE
# 8342           MACHADO  URBANA  VIAS PUBLICAS   CONTUNDENTES         A PIE
# 2775  VILLA SAN CARLOS  URBANA  VIAS PUBLICAS  ARMA DE FUEGO         A PIE
# 8899   ALTO JORDAN E18  URBANA  VIAS PUBLICAS  ARMA DE FUEGO         A PIE
# 3666    SECTOR GALERIA  URBANA     CAFETERIAS  ARMA DE FUEGO         A PIE
#
#              MOVIL AGRESOR  EDAD     GENERO ESTADO CIVIL CLASE EMPLEADO  \
# 6201                 A PIE  15.0  MASCULINO      SOLTERO    DESEMPLEADO
# 8342                 A PIE  81.0  MASCULINO        VIUDO    DESEMPLEADO
# 2775  PASAJERO MOTOCICLETA  43.0  MASCULINO       CASADO  INDEPENDIENTE
# 8899                 A PIE  32.0  MASCULINO  UNION LIBRE  INDEPENDIENTE
# 3666                 A PIE  39.0  MASCULINO      SOLTERO  INDEPENDIENTE
#
#          PROFESION ESCOLARIDAD PAIS NACE  CODIGO DANE  AÑO DE NACIMIENTO  \
# 6201  NO REPORTADO    PRIMARIA  COLOMBIA   76892000.0                0.0
# 8342  NO REPORTADO  SECUNDARIA  COLOMBIA    5212000.0             1934.0
# 2775  NO REPORTADO    PRIMARIA  COLOMBIA    8001000.0             1972.0
# 8899  NO REPORTADO  SECUNDARIA  COLOMBIA   76001000.0             1983.0
# 3666  NO REPORTADO    PRIMARIA  COLOMBIA    5615000.0             1976.0
#
#       CÉDULA                      CORREO
# 6201  60-818        bndobu9664@gmail.com
# 8342  64-414  qctcnd3108@unidatos.edu.co
# 2775  55-392        basnod6731@gmail.com
# 8899  57-157  gtmcog8608@unidatos.edu.co
# 3666  32-611  jashjl4886@unidatos.edu.co

# %% [markdown]
# ## 2. Fixing categorical column

# %%
# Creating a dictionary representing the valid departments for Colombia
departments_list = ['ANTIOQUIA', 'ATLÁNTICO', 'BOLÍVAR', 'BOYACÁ', 'CALDAS', 'CAQUETÁ',
       'CASANARE', 'CAUCA', 'CESAR', 'CHOCÓ', 'CÓRDOBA', 'META',
       'CUNDINAMARCA', 'HUILA', 'MAGDALENA', 'NARIÑO', 'PUTUMAYO',
       'RISARALDA', 'SANTANDER', 'SUCRE', 'TOLIMA', 'VALLE',
       'NORTE DE SANTANDER', 'GUAJIRA', 'QUINDÍO', 'SAN ANDRÉS Y PROVIDENCIA', 'ARAUCA',
       'GUAINÍA', 'VICHADA', 'VAUPÉS', 'GUAVIARE', 'AMAZONAS']

# %%
# Finding values not matching with the dictionary
homicides_df.loc[~homicides_df["DEPARTAMENTO"].isin(departments_list), "DEPARTAMENTO"].unique()
# Out:
# array(['SAN ANDRÉS', 'N. DE SANTANDER'], dtype=object)

# %% [markdown]
# <span style="color:red">TODO: Replace the values identified as error to a valid value from the dictionary.</span>
#
# <span style="color:red">Hint: You can use the replace() pandas function.</span>

# %%
homicides_df["DEPARTAMENTO"] = homicides_df["DEPARTAMENTO"].str.replace("SAN ANDRÉS", "SAN ANDRÉS Y PROVIDENCIA", regex=True)
homicides_df["DEPARTAMENTO"] = homicides_df["DEPARTAMENTO"].str.replace("N. DE SANTANDER", "NORTE DE SANTANDER", regex=True)

# %%
homicides_df
# Out:
#                   FECHA DEPARTAMENTO      MUNICIPIO     DIA  \
# 0       2021-01-01 6:00    ANTIOQUIA          AMAGÁ  Jueves
# 1       2021-01-01 9:00    ANTIOQUIA        BARBOSA  Jueves
# 2      2021-01-01 19:00    ANTIOQUIA       EL BAGRE  Jueves
# 3      2021-01-01 11:20    ANTIOQUIA         JARDÍN  Jueves
# 4      2021-01-01 15:00    ANTIOQUIA  MEDELLÍN (CT)   Juees
# ...                 ...          ...            ...     ...
# 12394  2021-12-31 15:42        VALLE     EL CERRITO  Jueves
# 12395  2021-12-31 19:04        VALLE      LA CUMBRE  Jueves
# 12396  2021-12-31 22:35        VALLE        PALMIRA  Jueves
# 12397  2021-12-31 14:30        VALLE         ZARZAL  Jueves
# 12398  2021-12-31 22:55      VICHADA       CUMARIBO  Jueves
#
#                          BARRIO    ZONA                      CLASE DE SITIO  \
# 0                     EL VOLCAN   RURAL                              TIENDA
# 1                VDA. MATASANOS   RURAL                       VIAS PUBLICAS
# 2                 PUERTO CLAVER   RURAL                  FINCAS Y SIMILARES
# 3                    CRISTIANIA   RURAL                  FINCAS Y SIMILARES
# 4      PICACHITO CNO REPORTADO6  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
# ...                         ...     ...                                 ...
# 12394              LA ESPERANZA  URBANA                       VIAS PUBLICAS
# 12395           CGTO BITACO E27   RURAL                       VIAS PUBLICAS
# 12396                    LORETO  URBANA                       VIAS PUBLICAS
# 12397         URB. EL ZARZALITO  URBANA                       VIAS PUBLICAS
# 12398                 EL CENTRO  URBANA                          HOSPITALES
#
#         ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO  \
# 0        ARMA BLANCA         A PIE         A PIE  44.0  MASCULINO
# 1        ARMA BLANCA         A PIE         A PIE  30.0  MASCULINO
# 2        ARMA BLANCA         A PIE         A PIE  33.0  MASCULINO
# 3        ARMA BLANCA         A PIE         A PIE  40.0  MASCULINO
# 4       CONTUNDENTES         A PIE         A PIE  66.0  MASCULINO
# ...              ...           ...           ...   ...        ...
# 12394  ARMA DE FUEGO         A PIE         A PIE  53.0   FEMENINO
# 12395  ARMA DE FUEGO         A PIE         A PIE  58.0  MASCULINO
# 12396  ARMA DE FUEGO         A PIE         A PIE  18.0   FEMENINO
# 12397  ARMA DE FUEGO         A PIE         A PIE  27.0  MASCULINO
# 12398    ARMA BLANCA         A PIE         A PIE  23.0  MASCULINO
#
#       ESTADO CIVIL       CLASE EMPLEADO     PROFESION ESCOLARIDAD  \
# 0           CASADO        INDEPENDIENTE  NO REPORTADO    PRIMARIA
# 1          SOLTERO          DESEMPLEADO  NO REPORTADO  SECUNDARIA
# 2      UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA
# 3           CASADO           AGRICULTOR  NO REPORTADO    PRIMARIA
# 4      UNION LIBRE          DESEMPLEADO  NO REPORTADO    PRIMARIA
# ...            ...                  ...           ...         ...
# 12394       CASADO  EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA
# 12395  UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA
# 12396      SOLTERO           ESTUDIANTE  NO REPORTADO  SECUNDARIA
# 12397      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# 12398      SOLTERO        INDEPENDIENTE  NO REPORTADO  SECUNDARIA
#
#           PAIS NACE  CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA  \
# 0          COLOMBIA    5030000.0             1971.0  42-908
# 1      NO REPORTADO    5079000.0             1985.0  15-183
# 2          COLOMBIA    5250000.0             1982.0  84-786
# 3          COLOMBIA    5364000.0             1975.0  31-289
# 4          COLOMBIA    5001000.0             1949.0  66-363
# ...             ...          ...                ...     ...
# 12394      COLOMBIA   76248000.0             1962.0  39-658
# 12395      COLOMBIA   76377000.0             1957.0  39-442
# 12396      COLOMBIA   76520000.0             1997.0  25-368
# 12397      COLOMBIA   76895000.0             1988.0  62-735
# 12398      COLOMBIA   99773000.0             1992.0  47-126
#
#                            CORREO
# 0      agbnqg2122@unidatos.edu.co
# 1            rbkeui3584@gmail.com
# 2      aorkhf9155@unidatos.edu.co
# 3      dhtemr6623@unidatos.edu.co
# 4      artatj9268@unidatos.edu.co
# ...                           ...
# 12394        nggiso7664@gmail.com
# 12395  correo4352@colombia.gov.co
# 12396  fktatq9245@unidatos.edu.co
# 12397        gafkup6393@gmail.com
# 12398   correo736@unidatos.edu.co
#
# [12395 rows x 21 columns]

# %% [markdown]
# ## 3. Analyzing potential duplicates

# %%
# Detecting duplicates by "CÉDULA" column
duplicates_by_cedula = homicides_df.loc[homicides_df["CÉDULA"].duplicated(keep=False)]

# %%
duplicates_by_cedula.shape
# Out:
# (1627, 21)

# %%
duplicates_by_cedula.sort_values("CÉDULA", ascending=True).head(6)
# Out:
#                   FECHA DEPARTAMENTO      MUNICIPIO      DIA  \
# 4041   2021-05-03 23:30        CAUCA       EL TAMBO  Domingo
# 3810    2021-04-26 3:00    ANTIOQUIA   SAN JERÓNIMO  Domingo
# 693     2021-01-19 5:30    ANTIOQUIA         SALGAR    Lunes
# 10796   2021-11-20 3:00        VALLE      CALI (CT)  Viernes
# 2386    2021-03-14 2:00         META  FUENTE DE ORO   Sábado
# 138     2021-01-02 6:20        CAUCA         SOTARA  Viernes
#
#                     BARRIO    ZONA                      CLASE DE SITIO  \
# 4041           LA VICTORIA   RURAL         BARES, CANTINAS Y SIMILARES
# 3810              LA PLAYA  URBANA  HOTELES, RESIDENCIAS, Y SIMILARES.
# 693              LA HABANA  URBANA                       VIAS PUBLICAS
# 10796   POTRERO GRANDE E21  URBANA                       VIAS PUBLICAS
# 2386   VEREDA PUERTO NUEVO   RURAL         BARES, CANTINAS Y SIMILARES
# 138                 CENTRO   RURAL                       VIAS PUBLICAS
#
#              ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO  \
# 4041        ARMA DE FUEGO         A PIE         A PIE  45.0  MASCULINO
# 3810   CUERDA/SOGA/CADENA         A PIE         A PIE  25.0  MASCULINO
# 693         ARMA DE FUEGO         A PIE         A PIE  58.0  MASCULINO
# 10796       ARMA DE FUEGO         A PIE         A PIE  21.0  MASCULINO
# 2386          ARMA BLANCA         A PIE         A PIE  42.0  MASCULINO
# 138           ARMA BLANCA         A PIE         A PIE  22.0  MASCULINO
#
#       ESTADO CIVIL       CLASE EMPLEADO     PROFESION ESCOLARIDAD PAIS NACE  \
# 4041   UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA  COLOMBIA
# 3810       SOLTERO        INDEPENDIENTE  NO REPORTADO  SECUNDARIA  COLOMBIA
# 693        SOLTERO           AGRICULTOR  NO REPORTADO    PRIMARIA  COLOMBIA
# 10796      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  COLOMBIA
# 2386       SOLTERO        INDEPENDIENTE  NO REPORTADO    PRIMARIA  COLOMBIA
# 138        SOLTERO    EMPLEADO EJERCITO  NO REPORTADO  SECUNDARIA  COLOMBIA
#
#        CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 4041    19256000.0             1970.0  10-048        aitufn1227@gmail.com
# 3810     5656000.0             1990.0  10-048  ibbcpu2509@unidatos.edu.co
# 693      5642000.0               57.0  10-079  unhoqj1172@unidatos.edu.co
# 10796   76001000.0             1994.0  10-079  iknnoj8430@unidatos.edu.co
# 2386    50287000.0             1973.0  10-255  afompq7113@unidatos.edu.co
# 138     19760000.0             1993.0  10-255  cobgqs8819@unidatos.edu.co

# %% [markdown]
# <span style="color:red">TODO: Delete records with "CÉDULA" duplicated.</span>
#
# <span style="color:red">Hint: You can use drop_duplicates() pandas function.</span>

# %%
duplicates_by_cedula = duplicates_by_cedula.drop_duplicates(subset=["CÉDULA"])

# %%
duplicates_by_cedula.sort_values("CÉDULA", ascending=True).head(6)
# Out:
#                   FECHA DEPARTAMENTO       MUNICIPIO      DIA  \
# 3810    2021-04-26 3:00    ANTIOQUIA    SAN JERÓNIMO  Domingo
# 693     2021-01-19 5:30    ANTIOQUIA          SALGAR    Lunes
# 138     2021-01-02 6:20        CAUCA          SOTARA  Viernes
# 2554   2021-03-19 10:05       NARIÑO         IPIALES   Jueves
# 10550  2021-11-14 16:05       CALDAS        SALAMINA   Sábado
# 1361   2021-02-09 21:30    ANTIOQUIA  CIUDAD BOLÍVAR     lune
#
#                        BARRIO    ZONA                      CLASE DE SITIO  \
# 3810                 LA PLAYA  URBANA  HOTELES, RESIDENCIAS, Y SIMILARES.
# 693                 LA HABANA  URBANA                       VIAS PUBLICAS
# 138                    CENTRO   RURAL                       VIAS PUBLICAS
# 2554                CHAMPAGTH  URBANA                       VIAS PUBLICAS
# 10550             VDA LA LOMA   RURAL                       VIAS PUBLICAS
# 1361   LA FLORESTA PARTE BAJA  URBANA                       VIAS PUBLICAS
#
#              ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO  \
# 3810   CUERDA/SOGA/CADENA         A PIE         A PIE  25.0  MASCULINO
# 693         ARMA DE FUEGO         A PIE         A PIE  58.0  MASCULINO
# 138           ARMA BLANCA         A PIE         A PIE  22.0  MASCULINO
# 2554          ARMA BLANCA         A PIE         A PIE  39.0  MASCULINO
# 10550         ARMA BLANCA         A PIE         A PIE  18.0  MASCULINO
# 1361        ARMA DE FUEGO         A PIE         A PIE  17.0  MASCULINO
#
#       ESTADO CIVIL     CLASE EMPLEADO     PROFESION ESCOLARIDAD PAIS NACE  \
# 3810       SOLTERO      INDEPENDIENTE  NO REPORTADO  SECUNDARIA  COLOMBIA
# 693        SOLTERO         AGRICULTOR  NO REPORTADO    PRIMARIA  COLOMBIA
# 138        SOLTERO  EMPLEADO EJERCITO  NO REPORTADO  SECUNDARIA  COLOMBIA
# 2554       SOLTERO      INDEPENDIENTE  NO REPORTADO    PRIMARIA  COLOMBIA
# 10550      SOLTERO         AGRICULTOR  NO REPORTADO    PRIMARIA  COLOMBIA
# 1361       SOLTERO      INDEPENDIENTE  NO REPORTADO    PRIMARIA  COLOMBIA
#
#        CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 3810     5656000.0             1990.0  10-048  ibbcpu2509@unidatos.edu.co
# 693      5642000.0               57.0  10-079  unhoqj1172@unidatos.edu.co
# 138     19760000.0             1993.0  10-255  cobgqs8819@unidatos.edu.co
# 2554    52356000.0             1976.0  10-327        kltnur7139@gmail.com
# 10550   17653000.0             1997.0  10-531  nkgqkf5128@unidatos.edu.co
# 1361     5101000.0             1998.0  10-722   correo187@unidatos.edu.co

# %% [markdown]
# ## 4. Fixing formats

# %%
# Using regular expressions for validating if "CÉDULA" values match the pattern XX-XXX
cedula_malformed = homicides_df.loc[homicides_df["CÉDULA"].apply(lambda x: (re.match("\d{2}-\d{3}", x) is None))]

# %%
cedula_malformed.shape
# Out:
# (28, 21)

# %%
cedula_malformed.head(4)
# Out:
#                  FECHA DEPARTAMENTO          MUNICIPIO      DIA  \
# 172   2021-01-03 11:00         META            MESETAS   Sábado
# 1114  2021-02-01 12:30    ATLÁNTICO  BARRANQUILLA (CT)  Domingo
# 2119  2021-03-06 15:30        VALLE          CALI (CT)  Viernes
# 3309  2021-04-11 10:30      CAQUETÁ     FLORENCIA (CT)   Sávado
#
#                    BARRIO    ZONA         CLASE DE SITIO      ARMA O MEDIO  \
# 172       VEREDA EL CAFRE   RURAL         ZONA SELVÁTICA  MINA ANTIPERSONA
# 1114               LA LUZ  URBANA          VIAS PUBLICAS     ARMA DE FUEGO
# 2119  QUINTAS DEL SOL E14  URBANA  DENTRO DE LA VIVIENDA       ARMA BLANCA
# 3309          VIA MORELIA   RURAL               CARCELES         CORTANTES
#
#      MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO ESTADO CIVIL  \
# 172          A PIE         A PIE  24.0  MASCULINO      SOLTERO
# 1114         A PIE         A PIE  29.0  MASCULINO      SOLTERO
# 2119         A PIE         A PIE  20.0   FEMENINO  UNION LIBRE
# 3309         A PIE         A PIE  23.0  MASCULINO      SOLTERO
#
#            CLASE EMPLEADO     PROFESION ESCOLARIDAD PAIS NACE  CODIGO DANE  \
# 172     EMPLEADO EJERCITO  NO REPORTADO  SECUNDARIA  COLOMBIA   50330000.0
# 1114        INDEPENDIENTE  NO REPORTADO    PRIMARIA  COLOMBIA    8001000.0
# 2119  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  COLOMBIA   76001000.0
# 3309        INDEPENDIENTE  NO REPORTADO    PRIMARIA  COLOMBIA   18001000.0
#
#       AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 172              1991.0  680-21        oohghd8899@gmail.com
# 1114             1986.0  140-17  correo5853@colombia.gov.co
# 2119             1995.0  975-31  ohbqrk3631@unidatos.edu.co
# 3309             1992.0  348-66  pdkqur8407@unidatos.edu.co

# %%
def corregir_cedula(cedula):
    if re.match(r'\d{2}-\d{3}', cedula):
        return cedula  
    else:
        cedula_corregida = re.sub(r'(\d{2})(\d{3})', r'\-1\-2', cedula)
        return cedula_corregida

# %%
homicides_df['CÉDULA'] = homicides_df['CÉDULA'].apply(corregir_cedula)

# %%
homicides_df['CÉDULA']
# Out:
# 0        42-908
# 1        15-183
# 2        84-786
# 3        31-289
# 4        66-363
#           ...
# 12394    39-658
# 12395    39-442
# 12396    25-368
# 12397    62-735
# 12398    47-126
# Name: CÉDULA, Length: 12395, dtype: object

# %% [markdown]
# <span style="color:red">TODO: Fix the malformed "CÉDULA" values.</span>

# %% [markdown]
# <span style="color:red">TODO: Make something similar to check and fix the "CORREO" column (PATTERN: 4 digits before the @, only .edu.co and .com domains are allowed)</span>

# %%
correo_malformed = homicides_df.loc[homicides_df["CORREO"].apply(lambda x: (re.match(r'^\d{4}@(\w+\.(edu\.co|com))$', x) is None))]

# %%
correo_malformed
# Out:
#                   FECHA DEPARTAMENTO      MUNICIPIO     DIA  \
# 0       2021-01-01 6:00    ANTIOQUIA          AMAGÁ  Jueves
# 1       2021-01-01 9:00    ANTIOQUIA        BARBOSA  Jueves
# 2      2021-01-01 19:00    ANTIOQUIA       EL BAGRE  Jueves
# 3      2021-01-01 11:20    ANTIOQUIA         JARDÍN  Jueves
# 4      2021-01-01 15:00    ANTIOQUIA  MEDELLÍN (CT)   Juees
# ...                 ...          ...            ...     ...
# 12394  2021-12-31 15:42        VALLE     EL CERRITO  Jueves
# 12395  2021-12-31 19:04        VALLE      LA CUMBRE  Jueves
# 12396  2021-12-31 22:35        VALLE        PALMIRA  Jueves
# 12397  2021-12-31 14:30        VALLE         ZARZAL  Jueves
# 12398  2021-12-31 22:55      VICHADA       CUMARIBO  Jueves
#
#                          BARRIO    ZONA                      CLASE DE SITIO  \
# 0                     EL VOLCAN   RURAL                              TIENDA
# 1                VDA. MATASANOS   RURAL                       VIAS PUBLICAS
# 2                 PUERTO CLAVER   RURAL                  FINCAS Y SIMILARES
# 3                    CRISTIANIA   RURAL                  FINCAS Y SIMILARES
# 4      PICACHITO CNO REPORTADO6  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
# ...                         ...     ...                                 ...
# 12394              LA ESPERANZA  URBANA                       VIAS PUBLICAS
# 12395           CGTO BITACO E27   RURAL                       VIAS PUBLICAS
# 12396                    LORETO  URBANA                       VIAS PUBLICAS
# 12397         URB. EL ZARZALITO  URBANA                       VIAS PUBLICAS
# 12398                 EL CENTRO  URBANA                          HOSPITALES
#
#         ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO  \
# 0        ARMA BLANCA         A PIE         A PIE  44.0  MASCULINO
# 1        ARMA BLANCA         A PIE         A PIE  30.0  MASCULINO
# 2        ARMA BLANCA         A PIE         A PIE  33.0  MASCULINO
# 3        ARMA BLANCA         A PIE         A PIE  40.0  MASCULINO
# 4       CONTUNDENTES         A PIE         A PIE  66.0  MASCULINO
# ...              ...           ...           ...   ...        ...
# 12394  ARMA DE FUEGO         A PIE         A PIE  53.0   FEMENINO
# 12395  ARMA DE FUEGO         A PIE         A PIE  58.0  MASCULINO
# 12396  ARMA DE FUEGO         A PIE         A PIE  18.0   FEMENINO
# 12397  ARMA DE FUEGO         A PIE         A PIE  27.0  MASCULINO
# 12398    ARMA BLANCA         A PIE         A PIE  23.0  MASCULINO
#
#       ESTADO CIVIL       CLASE EMPLEADO     PROFESION ESCOLARIDAD  \
# 0           CASADO        INDEPENDIENTE  NO REPORTADO    PRIMARIA
# 1          SOLTERO          DESEMPLEADO  NO REPORTADO  SECUNDARIA
# 2      UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA
# 3           CASADO           AGRICULTOR  NO REPORTADO    PRIMARIA
# 4      UNION LIBRE          DESEMPLEADO  NO REPORTADO    PRIMARIA
# ...            ...                  ...           ...         ...
# 12394       CASADO  EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA
# 12395  UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA
# 12396      SOLTERO           ESTUDIANTE  NO REPORTADO  SECUNDARIA
# 12397      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# 12398      SOLTERO        INDEPENDIENTE  NO REPORTADO  SECUNDARIA
#
#           PAIS NACE  CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA  \
# 0          COLOMBIA    5030000.0             1971.0  42-908
# 1      NO REPORTADO    5079000.0             1985.0  15-183
# 2          COLOMBIA    5250000.0             1982.0  84-786
# 3          COLOMBIA    5364000.0             1975.0  31-289
# 4          COLOMBIA    5001000.0             1949.0  66-363
# ...             ...          ...                ...     ...
# 12394      COLOMBIA   76248000.0             1962.0  39-658
# 12395      COLOMBIA   76377000.0             1957.0  39-442
# 12396      COLOMBIA   76520000.0             1997.0  25-368
# 12397      COLOMBIA   76895000.0             1988.0  62-735
# 12398      COLOMBIA   99773000.0             1992.0  47-126
#
#                            CORREO
# 0      agbnqg2122@unidatos.edu.co
# 1            rbkeui3584@gmail.com
# 2      aorkhf9155@unidatos.edu.co
# 3      dhtemr6623@unidatos.edu.co
# 4      artatj9268@unidatos.edu.co
# ...                           ...
# 12394        nggiso7664@gmail.com
# 12395  correo4352@colombia.gov.co
# 12396  fktatq9245@unidatos.edu.co
# 12397        gafkup6393@gmail.com
# 12398   correo736@unidatos.edu.co
#
# [12395 rows x 21 columns]

# %% [markdown]
# ## 5. Automating imputation of categorical values

# %%
homicides_df["DIA"].unique()
# Out:
# array(['Jueves', 'Juees', 'Jueces', 'juves', 'Juevrs', 'Viernes',
#        'Viermes', 'iernes', 'virnes', 'Vierens', 'Sábado', 'Sabadi',
#        'Sabado', 'sábad', 'Sávado', 'Ssbado', 'Domingo', 'Domungo',
#        'Doningo', 'domungo', 'Lunes', 'lune', 'Luns', 'Lumes', 'kunes',
#        'Lnues', 'Martes', 'Mates', 'Marte', 'mates', 'Miércoles',
#        'Miwrcoles', 'Mircoles', 'Voernes', 'domnigo', 'Maryes',
#        'Miercoles', 'miércles', 'Dominog', 'Msrtes', 'Mirrcoles'],
#       dtype=object)

# %%
# Calculating the distance between two words using the Levenshtein distance
pylev.levenshtein("sábado", "sabaod")
# Out:
# 3

# %%
pylev.levenshtein("sábado", "viernes")
# Out:
# 7

# %%
SequenceMatcher(None, "sábado", "sabaod").ratio()
# Out:
# 0.6666666666666666

# %%
SequenceMatcher(None, "sábado", "viernes").ratio()
# Out:
# 0.15384615384615385

# %% [markdown]
# <span style="color:red">How does SequenceMatcher works? How this differ from the Levenshtein distance?</span>

# %%
#SequenceMatcher se utiliza para medir la similitud entre secuencias y proporciona información detallada 
#sobre las similitudes y diferencias, mientras que la distancia de Levenshtein se utiliza 
#para medir la diferencia entre dos cadenas de texto calculando el número mínimo de operaciones
#necesarias para convertir una en otra.

# %% [markdown]
# <span style="color:red">TODO: Create a function to fix the digitation errors for the "DIA" column.</span>

# %%
homicides_df.reset_index(drop=True, inplace = True)

def corregir_dias(df, col):

    dias_correctos = ["Lunes", "Martes", "Miércoles", "Jueves", "Viernes", "Sábado", "Domingo"]

    ajuste =[]

    for index, row in df.iterrows():
      mejor_ratio = 0

      for i in dias_correctos:
        matches = SequenceMatcher(None,row[col], i).ratio()

        if matches > mejor_ratio:
          mejor_ratio = matches
          value = i

      ajuste.append(value)

    col_final = pd.DataFrame(ajuste)

    return col_final

homicides_df['dias_corregidos'] = corregir_dias(homicides_df, 'DIA')

# %%
homicides_df['dias_corregidos']
# Out:
# 0        Jueves
# 1        Jueves
# 2        Jueves
# 3        Jueves
# 4        Jueves
#           ...
# 12390    Jueves
# 12391    Jueves
# 12392    Jueves
# 12393    Jueves
# 12394    Jueves
# Name: dias_corregidos, Length: 12395, dtype: object

# %% [markdown]
# ## 6. Recalculation based on a different column

# %%
homicides_df[["AÑO DE NACIMIENTO", "EDAD"]].sample(10)
# Out:
#        AÑO DE NACIMIENTO  EDAD
# 10949             1964.0  51.0
# 6942              1983.0  32.0
# 10588             1991.0  24.0
# 3970              1995.0  20.0
# 10623             1975.0  40.0
# 163               1979.0  36.0
# 7711              1978.0  37.0
# 5550              1973.0  42.0
# 3560              1988.0  27.0
# 1345              1956.0  59.0

# %%
def fix_age(row):
    current_year = datetime.now().year
    row["AÑO DE NACIMIENTO"] = int(current_year - row["EDAD"])
    return row

homicides_df = homicides_df.apply(fix_age, axis=1)

# %%
homicides_df[["AÑO DE NACIMIENTO", "EDAD"]].sample(10)
# Out:
#        AÑO DE NACIMIENTO  EDAD
# 8515                1993  30.0
# 11817               1965  58.0
# 856                 1977  46.0
# 8112                1976  47.0
# 9658                1989  34.0
# 11006               1994  29.0
# 966                 1999  24.0
# 6934                2002  21.0
# 1032                1991  32.0
# 3450                1988  35.0

# %% [markdown]
# <span style="color:red">TODO: Fix the "AÑO DE NACIMIENTO" column using the column "EDAD".</span>

# %% [markdown]
# ## 7. Conclusion
#
# <span style="color:red">Make a summary of the different data quality problems found on the dataset, the data quality dimension that is related to and the implemented strategy for solving or mitigating that specific problem.</span>

# %%
# Problemas de Calidad

# Dentro del set de datos entregado, encontramos problemas de calidad relacionados con datos incompletos, 
# algunos errores de entrada durante la captura, igualmente, se detectaron problemas en estandarización de datos
# y presencia de registros duplicados en la base de datos, lo que puede llevar a la redundancia y la inconsistencia
# en los datos. 

# Dimensión de Calidad de Datos

# Dentro de los aspectos que fueron encontrados relacionados con la dimensión de calidad de datos, encontramos 
# inconvenientes con los temas de exactitud, integridad y completitud de la información. Otro de los temas relacionados, 
# es la unicidad que se relaciona con la presencia de duplicados en el conjunto de datos.

# Estrategia Implementada

# La estrategia ejecutada para asegurar la calidad de los datos, se centró en varias técnica de limpieza, iniciando con
# la eliminación de información con problemas de estandarización, posteriormente, se ejecutó una tarea para eliminar 
# datos duplicados en un campo clave de las consultas que era la identificación de la persona, con esto asegurábamos 
# el listado de personas únicos y relacionados por departamento estandarizado. Con el fin de contar con información 
# integra, se corrigieron los temas de formato de la cedula, continuando con el aseguramiento de la identificación de 
# las personas. Continuando con las herramientas para estandarización y limpieza, se aseguran los datos de contacto
# e información relevante sobre los días de los homicidios y edad de las personas relacionadas en el dataset.
